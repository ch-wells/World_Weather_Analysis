# %%
import random
import numpy as np
import pandas as pd
from citipy import citipy
import requests
from config import weather_api_key
import time
from datetime import datetime

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.

for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
#         Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
    
#         Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        current_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": current_description})

# If an error is experienced, skip the city.
    except KeyError:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | luanda
# Processing Record 2 of Set 1 | fortuna
# Processing Record 3 of Set 1 | sibu
# Processing Record 4 of Set 1 | nouakchott
# Processing Record 5 of Set 1 | marawi
# Processing Record 6 of Set 1 | longyearbyen
# Processing Record 7 of Set 1 | vaini
# Processing Record 8 of Set 1 | faanui
# Processing Record 9 of Set 1 | stornoway
# Processing Record 10 of Set 1 | ribeira grande
# Processing Record 11 of Set 1 | vila velha
# Processing Record 12 of Set 1 | airai
# Processing Record 13 of Set 1 | bara
# Processing Record 14 of Set 1 | ushuaia
# Processing Record 15 of Set 1 | sao filipe
# Processing Record 16 of Set 1 | nelson bay
# Processing Record 17 of Set 1 | klaksvik
# Processing Record 18 of Set 1 | port alfred
# Processing Record 19 of Set 1 | saskylakh
# Processing Record 20 of Set 1 | qaanaaq
# Processing Record 21 of Set 1 | nouadhibou
# Processing Record 22 of Set 1 | kapaa
# Processing Record 23 of Set 1 | berlevag
# Processing Record 24 of Set 1 | irbit
# Processing Record 25 of Set 1 | niksic
# Processing Record 26 of Set 1 | chicama
# Processing Record 27 of Set 1 | mataura
# Processing Record 28 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 29 of Set 1 | clyde river
# Processing Record 30 of Set 1 | salalah
# Processing Record 31 of Set 1 | hithadhoo
# Processing Record 32 of Set 1 | upernavik
# Processing Record 33 of Set 1 | carnarvon
# Processing Record 34 of Set 1 | turbo
# Processing Record 35 of Set 1 | east london
# Processing Record 36 of Set 1 | ust-kuyga
# Processing Record 37 of Set 1 | albany
# Processing Record 38 of Set 1 | laguna
# Processing Record 39 of Set 1 | imbituba
# Processing Record 40 of Set 1 | arraial do cabo
# Processing Record 41 of Set 1 | mogadouro
# Processing Record 42 of Set 1 | severo-kurilsk
# Processing Record 43 of Set 1 | busselton
# Processing Record 44 of Set 1 | codrington
# Processing Record 45 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 46 of Set 1 | hobart
# Processing Record 47 of Set 1 | bafq
# Processing Record 48 of Set 1 | rikitea
# Processing Record 49 of Set 1 | ugoofaaru
# Processing Record 50 of Set 1 | constitucion
# Processing Record 1 of Set 2 | coahuayana
# Processing Record 2 of Set 2 | san carlos de bariloche
# Processing Record 3 of Set 2 | shubarshi
# Processing Record 4 of Set 2 | camocim
# Processing Record 5 of Set 2 | hilo
# Processing Record 6 of Set 2 | tabuk
# Processing Record 7 of Set 2 | cape town
# Processing Record 8 of Set 2 | komsomolskiy
# Processing Record 9 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 10 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 11 of Set 2 | grindavik
# Processing Record 12 of Set 2 | nieuw amsterdam
# Processing Record 13 of Set 2 | strausberg
# Processing Record 14 of Set 2 | sedelnikovo
# City not found. Skipping...
# Processing Record 15 of Set 2 | maniitsoq
# Processing Record 16 of Set 2 | ancud
# Processing Record 17 of Set 2 | kemijarvi
# Processing Record 18 of Set 2 | padang
# Processing Record 19 of Set 2 | petropavlovsk-kamchatskiy
# Processing Record 20 of Set 2 | mehran
# Processing Record 21 of Set 2 | uspenka
# Processing Record 22 of Set 2 | sitka
# Processing Record 23 of Set 2 | palauig
# Processing Record 24 of Set 2 | cidreira
# Processing Record 25 of Set 2 | sao joao do paraiso
# Processing Record 26 of Set 2 | saint-philippe
# Processing Record 27 of Set 2 | ola
# Processing Record 28 of Set 2 | kruisfontein
# Processing Record 29 of Set 2 | bengkulu
# Processing Record 30 of Set 2 | merauke
# Processing Record 31 of Set 2 | melendugno
# Processing Record 32 of Set 2 | geraldton
# Processing Record 33 of Set 2 | yellowknife
# Processing Record 34 of Set 2 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 35 of Set 2 | flinders
# Processing Record 36 of Set 2 | walvis bay
# Processing Record 37 of Set 2 | jamestown
# Processing Record 38 of Set 2 | goksun
# Processing Record 39 of Set 2 | visnes
# Processing Record 40 of Set 2 | kenai
# Processing Record 41 of Set 2 | kuri
# Processing Record 42 of Set 2 | punta arenas
# Processing Record 43 of Set 2 | nabire
# Processing Record 44 of Set 2 | san luis
# Processing Record 45 of Set 2 | oudtshoorn
# Processing Record 46 of Set 2 | chuy
# Processing Record 47 of Set 2 | mahebourg
# Processing Record 48 of Set 2 | bani walid
# Processing Record 49 of Set 2 | sinnamary
# Processing Record 50 of Set 2 | torbay
# Processing Record 1 of Set 3 | yamada
# Processing Record 2 of Set 3 | simao
# Processing Record 3 of Set 3 | port hedland
# Processing Record 4 of Set 3 | bluff
# Processing Record 5 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 6 of Set 3 | iqaluit
# Processing Record 7 of Set 3 | mao
# Processing Record 8 of Set 3 | bredasdorp
# Processing Record 9 of Set 3 | cherskiy
# Processing Record 10 of Set 3 | butaritari
# Processing Record 11 of Set 3 | bilma
# Processing Record 12 of Set 3 | tuktoyaktuk
# Processing Record 13 of Set 3 | nikolskoye
# Processing Record 14 of Set 3 | natal
# Processing Record 15 of Set 3 | katsuura
# Processing Record 16 of Set 3 | inuvik
# Processing Record 17 of Set 3 | lagos
# Processing Record 18 of Set 3 | nanortalik
# Processing Record 19 of Set 3 | mendahara
# City not found. Skipping...
# Processing Record 20 of Set 3 | emerald
# Processing Record 21 of Set 3 | santiago del estero
# Processing Record 22 of Set 3 | bartica
# Processing Record 23 of Set 3 | tiksi
# Processing Record 24 of Set 3 | stephenville
# Processing Record 25 of Set 3 | waipawa
# Processing Record 26 of Set 3 | gazojak
# Processing Record 27 of Set 3 | georgetown
# Processing Record 28 of Set 3 | san
# Processing Record 29 of Set 3 | new norfolk
# Processing Record 30 of Set 3 | pangoa
# Processing Record 31 of Set 3 | hambantota
# Processing Record 32 of Set 3 | khatanga
# Processing Record 33 of Set 3 | guerrero negro
# Processing Record 34 of Set 3 | jishou
# Processing Record 35 of Set 3 | fort myers beach
# Processing Record 36 of Set 3 | datong
# Processing Record 37 of Set 3 | barrow
# Processing Record 38 of Set 3 | dikson
# Processing Record 39 of Set 3 | hofn
# Processing Record 40 of Set 3 | ilulissat
# Processing Record 41 of Set 3 | touros
# Processing Record 42 of Set 3 | rock springs
# Processing Record 43 of Set 3 | atuona
# Processing Record 44 of Set 3 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 45 of Set 3 | santa vitoria
# Processing Record 46 of Set 3 | sur
# Processing Record 47 of Set 3 | wajima
# Processing Record 48 of Set 3 | bati
# Processing Record 49 of Set 3 | uwayl
# City not found. Skipping...
# Processing Record 50 of Set 3 | tarata
# Processing Record 1 of Set 4 | nuuk
# Processing Record 2 of Set 4 | san patricio
# Processing Record 3 of Set 4 | vilhena
# Processing Record 4 of Set 4 | katha
# City not found. Skipping...
# Processing Record 5 of Set 4 | souillac
# Processing Record 6 of Set 4 | payo
# Processing Record 7 of Set 4 | bereda
# Processing Record 8 of Set 4 | kalemie
# Processing Record 9 of Set 4 | rungata
# City not found. Skipping...
# Processing Record 10 of Set 4 | harper
# Processing Record 11 of Set 4 | pisco
# Processing Record 12 of Set 4 | canutama
# Processing Record 13 of Set 4 | victoria
# Processing Record 14 of Set 4 | fairbanks
# Processing Record 15 of Set 4 | kasempa
# Processing Record 16 of Set 4 | mangrol
# Processing Record 17 of Set 4 | thompson
# Processing Record 18 of Set 4 | praya
# Processing Record 19 of Set 4 | yulara
# Processing Record 20 of Set 4 | bambous virieux
# Processing Record 21 of Set 4 | campoverde
# Processing Record 22 of Set 4 | avarua
# Processing Record 23 of Set 4 | shache
# Processing Record 24 of Set 4 | vanimo
# Processing Record 25 of Set 4 | dingle
# Processing Record 26 of Set 4 | pandamatenga
# Processing Record 27 of Set 4 | kaitangata
# Processing Record 28 of Set 4 | port elizabeth
# Processing Record 29 of Set 4 | hermanus
# Processing Record 30 of Set 4 | pangai
# Processing Record 31 of Set 4 | seoul
# Processing Record 32 of Set 4 | paamiut
# Processing Record 33 of Set 4 | saint-louis
# Processing Record 34 of Set 4 | haines junction
# Processing Record 35 of Set 4 | yar-sale
# Processing Record 36 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 37 of Set 4 | puerto ayora
# Processing Record 38 of Set 4 | sao miguel do araguaia
# Processing Record 39 of Set 4 | castanos
# Processing Record 40 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 41 of Set 4 | westport
# Processing Record 42 of Set 4 | valparaiso
# Processing Record 43 of Set 4 | hasaki
# Processing Record 44 of Set 4 | cabo san lucas
# Processing Record 45 of Set 4 | margate
# Processing Record 46 of Set 4 | takhatpur
# Processing Record 47 of Set 4 | antofagasta
# Processing Record 48 of Set 4 | kavaratti
# Processing Record 49 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 50 of Set 4 | bolshaya murta
# City not found. Skipping...
# Processing Record 1 of Set 5 | vestmannaeyjar
# Processing Record 2 of Set 5 | nongan
# Processing Record 3 of Set 5 | riyadh
# Processing Record 4 of Set 5 | troyes
# Processing Record 5 of Set 5 | fare
# Processing Record 6 of Set 5 | ler
# Processing Record 7 of Set 5 | schwaz
# Processing Record 8 of Set 5 | dubbo
# Processing Record 9 of Set 5 | juruti
# Processing Record 10 of Set 5 | thinadhoo
# Processing Record 11 of Set 5 | arlit
# Processing Record 12 of Set 5 | englehart
# Processing Record 13 of Set 5 | norman wells
# Processing Record 14 of Set 5 | port lincoln
# Processing Record 15 of Set 5 | rapid valley
# Processing Record 16 of Set 5 | guanare
# Processing Record 17 of Set 5 | jinchang
# Processing Record 18 of Set 5 | samarinda
# Processing Record 19 of Set 5 | george town
# Processing Record 20 of Set 5 | batagay
# Processing Record 21 of Set 5 | mikhaylovka
# Processing Record 22 of Set 5 | isangel
# Processing Record 23 of Set 5 | muromtsevo
# Processing Record 24 of Set 5 | jining
# Processing Record 25 of Set 5 | debre tabor
# Processing Record 26 of Set 5 | tasiilaq
# Processing Record 27 of Set 5 | inirida
# Processing Record 28 of Set 5 | rurrenabaque
# Processing Record 29 of Set 5 | fort nelson
# Processing Record 30 of Set 5 | notre-dame-du-lac
# Processing Record 31 of Set 5 | warqla
# City not found. Skipping...
# Processing Record 32 of Set 5 | vila do maio
# Processing Record 33 of Set 5 | rawson
# Processing Record 34 of Set 5 | lata
# Processing Record 35 of Set 5 | san cristobal
# Processing Record 36 of Set 5 | svodna
# Processing Record 37 of Set 5 | sargodha
# Processing Record 38 of Set 5 | lorengau
# Processing Record 39 of Set 5 | bathsheba
# Processing Record 40 of Set 5 | comodoro rivadavia
# Processing Record 41 of Set 5 | husavik
# Processing Record 42 of Set 5 | saint george
# Processing Record 43 of Set 5 | lompoc
# Processing Record 44 of Set 5 | meulaboh
# Processing Record 45 of Set 5 | tiznit
# Processing Record 46 of Set 5 | carutapera
# Processing Record 47 of Set 5 | ixtapa
# Processing Record 48 of Set 5 | gamba
# Processing Record 49 of Set 5 | hovd
# Processing Record 50 of Set 5 | bumba
# Processing Record 1 of Set 6 | sumbawa
# City not found. Skipping...
# Processing Record 2 of Set 6 | olafsvik
# Processing Record 3 of Set 6 | ahipara
# Processing Record 4 of Set 6 | greenfield
# Processing Record 5 of Set 6 | ironton
# Processing Record 6 of Set 6 | eskasem
# City not found. Skipping...
# Processing Record 7 of Set 6 | puerto baquerizo moreno
# Processing Record 8 of Set 6 | lagoa
# Processing Record 9 of Set 6 | chino valley
# Processing Record 10 of Set 6 | namwala
# Processing Record 11 of Set 6 | makakilo city
# Processing Record 12 of Set 6 | balabac
# Processing Record 13 of Set 6 | marzuq
# Processing Record 14 of Set 6 | san quintin
# Processing Record 15 of Set 6 | okha
# Processing Record 16 of Set 6 | vardo
# Processing Record 17 of Set 6 | toowoomba
# Processing Record 18 of Set 6 | te anau
# Processing Record 19 of Set 6 | mednogorsk
# Processing Record 20 of Set 6 | griffith
# Processing Record 21 of Set 6 | santa marta
# Processing Record 22 of Set 6 | samara
# Processing Record 23 of Set 6 | morozovsk
# Processing Record 24 of Set 6 | valdez
# Processing Record 25 of Set 6 | lebu
# Processing Record 26 of Set 6 | basay
# Processing Record 27 of Set 6 | port blair
# Processing Record 28 of Set 6 | montepuez
# Processing Record 29 of Set 6 | bacuit
# City not found. Skipping...
# Processing Record 30 of Set 6 | masindi
# Processing Record 31 of Set 6 | garowe
# Processing Record 32 of Set 6 | sao joao da barra
# Processing Record 33 of Set 6 | vegreville
# Processing Record 34 of Set 6 | paine
# Processing Record 35 of Set 6 | mamallapuram
# Processing Record 36 of Set 6 | port-gentil
# Processing Record 37 of Set 6 | smithers
# Processing Record 38 of Set 6 | cabedelo
# Processing Record 39 of Set 6 | provideniya
# Processing Record 40 of Set 6 | yangambi
# Processing Record 41 of Set 6 | chokurdakh
# Processing Record 42 of Set 6 | malindi
# Processing Record 43 of Set 6 | sibolga
# Processing Record 44 of Set 6 | ganzhou
# Processing Record 45 of Set 6 | necochea
# Processing Record 46 of Set 6 | doctor arroyo
# Processing Record 47 of Set 6 | quatre cocos
# Processing Record 48 of Set 6 | kidal
# Processing Record 49 of Set 6 | esperance
# Processing Record 50 of Set 6 | asau
# Processing Record 1 of Set 7 | velyka oleksandrivka
# Processing Record 2 of Set 7 | dalvik
# Processing Record 3 of Set 7 | myitkyina
# Processing Record 4 of Set 7 | coronado
# Processing Record 5 of Set 7 | linhares
# Processing Record 6 of Set 7 | orocue
# Processing Record 7 of Set 7 | nakamura
# Processing Record 8 of Set 7 | kwekwe
# Processing Record 9 of Set 7 | najran
# Processing Record 10 of Set 7 | goya
# Processing Record 11 of Set 7 | kodiak
# Processing Record 12 of Set 7 | aykhal
# Processing Record 13 of Set 7 | raga
# Processing Record 14 of Set 7 | lazaro cardenas
# Processing Record 15 of Set 7 | pevek
# Processing Record 16 of Set 7 | duz
# City not found. Skipping...
# Processing Record 17 of Set 7 | vikulovo
# Processing Record 18 of Set 7 | castro
# Processing Record 19 of Set 7 | mehamn
# Processing Record 20 of Set 7 | great yarmouth
# Processing Record 21 of Set 7 | salina cruz
# Processing Record 22 of Set 7 | ranipur
# Processing Record 23 of Set 7 | cayenne
# Processing Record 24 of Set 7 | hami
# Processing Record 25 of Set 7 | socorro
# Processing Record 26 of Set 7 | saint-augustin
# Processing Record 27 of Set 7 | lucea
# Processing Record 28 of Set 7 | tual
# Processing Record 29 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 30 of Set 7 | aklavik
# Processing Record 31 of Set 7 | vallenar
# Processing Record 32 of Set 7 | lynn haven
# Processing Record 33 of Set 7 | templin
# Processing Record 34 of Set 7 | leningradskiy
# Processing Record 35 of Set 7 | kawalu
# Processing Record 36 of Set 7 | taoudenni
# Processing Record 37 of Set 7 | izhma
# Processing Record 38 of Set 7 | labuhan
# Processing Record 39 of Set 7 | hamilton
# Processing Record 40 of Set 7 | kimberley
# Processing Record 41 of Set 7 | kuva
# City not found. Skipping...
# Processing Record 42 of Set 7 | kikwit
# Processing Record 43 of Set 7 | bloomfield
# Processing Record 44 of Set 7 | saint-paul
# Processing Record 45 of Set 7 | morondava
# Processing Record 46 of Set 7 | grand gaube
# Processing Record 47 of Set 7 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 48 of Set 7 | mwinilunga
# Processing Record 49 of Set 7 | rio gallegos
# Processing Record 50 of Set 7 | mar del plata
# Processing Record 1 of Set 8 | lasa
# Processing Record 2 of Set 8 | greenwood
# Processing Record 3 of Set 8 | narsaq
# Processing Record 4 of Set 8 | port hueneme
# Processing Record 5 of Set 8 | rypin
# Processing Record 6 of Set 8 | karasjok
# Processing Record 7 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 8 of Set 8 | mackay
# Processing Record 9 of Set 8 | kalmunai
# Processing Record 10 of Set 8 | kokopo
# Processing Record 11 of Set 8 | amazar
# Processing Record 12 of Set 8 | zhicheng
# Processing Record 13 of Set 8 | krasnyy yar
# Processing Record 14 of Set 8 | dudinka
# Processing Record 15 of Set 8 | bahia blanca
# Processing Record 16 of Set 8 | tura
# Processing Record 17 of Set 8 | sorland
# Processing Record 18 of Set 8 | ponta do sol
# Processing Record 19 of Set 8 | atar
# Processing Record 20 of Set 8 | tagusao
# Processing Record 21 of Set 8 | kavieng
# Processing Record 22 of Set 8 | san joaquin
# Processing Record 23 of Set 8 | kokstad
# Processing Record 24 of Set 8 | wajir
# Processing Record 25 of Set 8 | kloulklubed
# Processing Record 26 of Set 8 | poum
# Processing Record 27 of Set 8 | samalaeulu
# City not found. Skipping...
# Processing Record 28 of Set 8 | manta
# Processing Record 29 of Set 8 | aquiraz
# Processing Record 30 of Set 8 | honningsvag
# Processing Record 31 of Set 8 | iquique
# Processing Record 32 of Set 8 | auki
# Processing Record 33 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 34 of Set 8 | beidao
# Processing Record 35 of Set 8 | lahad datu
# Processing Record 36 of Set 8 | srednekolymsk
# Processing Record 37 of Set 8 | sorvag
# City not found. Skipping...
# Processing Record 38 of Set 8 | buala
# Processing Record 39 of Set 8 | okhotsk
# Processing Record 40 of Set 8 | maputo
# Processing Record 41 of Set 8 | coquimbo
# Processing Record 42 of Set 8 | la ronge
# Processing Record 43 of Set 8 | huancabamba
# Processing Record 44 of Set 8 | oussouye
# Processing Record 45 of Set 8 | hirara
# Processing Record 46 of Set 8 | tautira
# Processing Record 47 of Set 8 | saldanha
# Processing Record 48 of Set 8 | adeje
# Processing Record 49 of Set 8 | meybod
# Processing Record 50 of Set 8 | monterey
# Processing Record 1 of Set 9 | alice springs
# Processing Record 2 of Set 9 | evensk
# Processing Record 3 of Set 9 | northam
# Processing Record 4 of Set 9 | chapais
# Processing Record 5 of Set 9 | vieux-habitants
# Processing Record 6 of Set 9 | barentsburg
# City not found. Skipping...
# Processing Record 7 of Set 9 | agirish
# Processing Record 8 of Set 9 | sheridan
# Processing Record 9 of Set 9 | mnogovershinnyy
# Processing Record 10 of Set 9 | el estor
# Processing Record 11 of Set 9 | lerum
# Processing Record 12 of Set 9 | havoysund
# Processing Record 13 of Set 9 | new amsterdam
# Processing Record 14 of Set 9 | onega
# Processing Record 15 of Set 9 | ulladulla
# Processing Record 16 of Set 9 | krasnoyarsk-45
# City not found. Skipping...
# Processing Record 17 of Set 9 | soyo
# Processing Record 18 of Set 9 | shebunino
# Processing Record 19 of Set 9 | nara
# Processing Record 20 of Set 9 | englewood
# Processing Record 21 of Set 9 | sydney
# Processing Record 22 of Set 9 | ponta delgada
# Processing Record 23 of Set 9 | fuerte olimpo
# Processing Record 24 of Set 9 | coihaique
# Processing Record 25 of Set 9 | ocos
# Processing Record 26 of Set 9 | dolbeau
# City not found. Skipping...
# Processing Record 27 of Set 9 | tafresh
# Processing Record 28 of Set 9 | marigot
# Processing Record 29 of Set 9 | biak
# Processing Record 30 of Set 9 | sawakin
# Processing Record 31 of Set 9 | itoman
# Processing Record 32 of Set 9 | ahuimanu
# Processing Record 33 of Set 9 | raymond
# Processing Record 34 of Set 9 | xinxiang
# Processing Record 35 of Set 9 | vung tau
# Processing Record 36 of Set 9 | muros
# Processing Record 37 of Set 9 | ostrovnoy
# Processing Record 38 of Set 9 | booue
# Processing Record 39 of Set 9 | panjab
# Processing Record 40 of Set 9 | ust-omchug
# Processing Record 41 of Set 9 | zhigansk
# Processing Record 42 of Set 9 | pa sang
# Processing Record 43 of Set 9 | pierre
# Processing Record 44 of Set 9 | sao felix do xingu
# Processing Record 45 of Set 9 | crab hill
# City not found. Skipping...
# Processing Record 46 of Set 9 | pacific grove
# Processing Record 47 of Set 9 | vangaindrano
# Processing Record 48 of Set 9 | ketchikan
# Processing Record 49 of Set 9 | kuntaur
# Processing Record 50 of Set 9 | ngukurr
# City not found. Skipping...
# Processing Record 1 of Set 10 | scottsburgh
# City not found. Skipping...
# Processing Record 2 of Set 10 | zyryanka
# Processing Record 3 of Set 10 | kutum
# Processing Record 4 of Set 10 | bandar-e torkaman
# City not found. Skipping...
# Processing Record 5 of Set 10 | sukumo
# Processing Record 6 of Set 10 | zavidovici
# Processing Record 7 of Set 10 | sosva
# Processing Record 8 of Set 10 | roald
# Processing Record 9 of Set 10 | mizdah
# Processing Record 10 of Set 10 | caravelas
# Processing Record 11 of Set 10 | goderich
# Processing Record 12 of Set 10 | vila franca do campo
# Processing Record 13 of Set 10 | biltine
# Processing Record 14 of Set 10 | bethel
# Processing Record 15 of Set 10 | umzimvubu
# City not found. Skipping...
# Processing Record 16 of Set 10 | goundam
# Processing Record 17 of Set 10 | tazovskiy
# Processing Record 18 of Set 10 | sauk rapids
# Processing Record 19 of Set 10 | nishihara
# Processing Record 20 of Set 10 | samatau
# City not found. Skipping...
# Processing Record 21 of Set 10 | balakhta
# Processing Record 22 of Set 10 | hervey bay
# Processing Record 23 of Set 10 | yining
# Processing Record 24 of Set 10 | russell
# Processing Record 25 of Set 10 | singaraja
# Processing Record 26 of Set 10 | nioro
# Processing Record 27 of Set 10 | penzance
# Processing Record 28 of Set 10 | louisbourg
# City not found. Skipping...
# Processing Record 29 of Set 10 | mogadishu
# Processing Record 30 of Set 10 | new ulm
# Processing Record 31 of Set 10 | mutoko
# Processing Record 32 of Set 10 | turukhansk
# Processing Record 33 of Set 10 | aberfeldy
# Processing Record 34 of Set 10 | zhenjiang
# Processing Record 35 of Set 10 | maceo
# Processing Record 36 of Set 10 | sweetwater
# Processing Record 37 of Set 10 | soller
# Processing Record 38 of Set 10 | fevralsk
# City not found. Skipping...
# Processing Record 39 of Set 10 | svobodnyy
# Processing Record 40 of Set 10 | merida
# Processing Record 41 of Set 10 | orchard homes
# Processing Record 42 of Set 10 | la asuncion
# Processing Record 43 of Set 10 | ciudad bolivar
# Processing Record 44 of Set 10 | praia da vitoria
# Processing Record 45 of Set 10 | camana
# Processing Record 46 of Set 10 | gao
# Processing Record 47 of Set 10 | vaitupu
# City not found. Skipping...
# Processing Record 48 of Set 10 | tsihombe
# City not found. Skipping...
# Processing Record 49 of Set 10 | camargo
# Processing Record 50 of Set 10 | esmeraldas
# Processing Record 1 of Set 11 | langres
# Processing Record 2 of Set 11 | baghmara
# Processing Record 3 of Set 11 | pine bluff
# Processing Record 4 of Set 11 | sabang
# Processing Record 5 of Set 11 | wanning
# Processing Record 6 of Set 11 | nueva gerona
# Processing Record 7 of Set 11 | novikovo
# Processing Record 8 of Set 11 | saleaula
# City not found. Skipping...
# Processing Record 9 of Set 11 | beringovskiy
# Processing Record 10 of Set 11 | moyale
# Processing Record 11 of Set 11 | buraydah
# Processing Record 12 of Set 11 | naze
# Processing Record 13 of Set 11 | marystown
# Processing Record 14 of Set 11 | nome
# Processing Record 15 of Set 11 | aksha
# Processing Record 16 of Set 11 | el alto
# Processing Record 17 of Set 11 | tamale
# Processing Record 18 of Set 11 | severnyy
# Processing Record 19 of Set 11 | langsa
# Processing Record 20 of Set 11 | bilibino
# Processing Record 21 of Set 11 | benito juarez
# Processing Record 22 of Set 11 | kungurtug
# Processing Record 23 of Set 11 | neya
# Processing Record 24 of Set 11 | san bernardo
# Processing Record 25 of Set 11 | yeletskiy
# City not found. Skipping...
# Processing Record 26 of Set 11 | baykit
# Processing Record 27 of Set 11 | turan
# Processing Record 28 of Set 11 | san policarpo
# Processing Record 29 of Set 11 | tonj
# Processing Record 30 of Set 11 | norrtalje
# Processing Record 31 of Set 11 | ronnede
# Processing Record 32 of Set 11 | ures
# Processing Record 33 of Set 11 | marsa matruh
# Processing Record 34 of Set 11 | ejido
# Processing Record 35 of Set 11 | giyani
# Processing Record 36 of Set 11 | abaza
# Processing Record 37 of Set 11 | moundou
# Processing Record 38 of Set 11 | axim
# Processing Record 39 of Set 11 | kahului
# Processing Record 40 of Set 11 | general roca
# Processing Record 41 of Set 11 | palana
# Processing Record 42 of Set 11 | vanavara
# Processing Record 43 of Set 11 | amderma
# City not found. Skipping...
# Processing Record 44 of Set 11 | jalu
# Processing Record 45 of Set 11 | solhan
# Processing Record 46 of Set 11 | robertson
# Processing Record 47 of Set 11 | lavrentiya
# Processing Record 48 of Set 11 | mount isa
# Processing Record 49 of Set 11 | paracuru
# Processing Record 50 of Set 11 | severo-yeniseyskiy
# Processing Record 1 of Set 12 | bima
# Processing Record 2 of Set 12 | bijar
# Processing Record 3 of Set 12 | viligili
# City not found. Skipping...
# Processing Record 4 of Set 12 | namibe
# Processing Record 5 of Set 12 | lerwick
# Processing Record 6 of Set 12 | cardston
# Processing Record 7 of Set 12 | skibbereen
# Processing Record 8 of Set 12 | nantucket
# Processing Record 9 of Set 12 | west bay
# Processing Record 10 of Set 12 | bintulu
# Processing Record 11 of Set 12 | nichinan
# Processing Record 12 of Set 12 | caconda
# Processing Record 13 of Set 12 | kamenskoye
# City not found. Skipping...
# Processing Record 14 of Set 12 | puerto lopez
# Processing Record 15 of Set 12 | nyuksenitsa
# Processing Record 16 of Set 12 | price
# Processing Record 17 of Set 12 | imperia
# Processing Record 18 of Set 12 | del rio
# Processing Record 19 of Set 12 | ekibastuz
# Processing Record 20 of Set 12 | bileca
# Processing Record 21 of Set 12 | isakly
# Processing Record 22 of Set 12 | pangnirtung
# Processing Record 23 of Set 12 | rennes
# Processing Record 24 of Set 12 | belur
# Processing Record 25 of Set 12 | broome
# Processing Record 26 of Set 12 | kashary
# Processing Record 27 of Set 12 | matay
# Processing Record 28 of Set 12 | whittlesea
# Processing Record 29 of Set 12 | palabuhanratu
# City not found. Skipping...
# Processing Record 30 of Set 12 | dhadar
# Processing Record 31 of Set 12 | areka
# Processing Record 32 of Set 12 | port hardy
# Processing Record 33 of Set 12 | itaituba
# Processing Record 34 of Set 12 | vasterhaninge
# Processing Record 35 of Set 12 | benguela
# Processing Record 36 of Set 12 | kurya
# Processing Record 37 of Set 12 | general pico
# Processing Record 38 of Set 12 | taft
# Processing Record 39 of Set 12 | krasnoselkup
# Processing Record 40 of Set 12 | maloy
# Processing Record 41 of Set 12 | halifax
# Processing Record 42 of Set 12 | toppenish
# Processing Record 43 of Set 12 | zapotiltic
# Processing Record 44 of Set 12 | oktyabrskiy
# Processing Record 45 of Set 12 | myrtle beach
# Processing Record 46 of Set 12 | palmar
# Processing Record 47 of Set 12 | beboto
# Processing Record 48 of Set 12 | saint anthony
# Processing Record 49 of Set 12 | kropotkin
# Processing Record 50 of Set 12 | north bend
# Processing Record 1 of Set 13 | ko samui
# Processing Record 2 of Set 13 | jumla
# Processing Record 3 of Set 13 | taonan
# Processing Record 4 of Set 13 | sinjar
# Processing Record 5 of Set 13 | smirnykh
# Processing Record 6 of Set 13 | colares
# Processing Record 7 of Set 13 | naftah
# City not found. Skipping...
# Processing Record 8 of Set 13 | wenling
# Processing Record 9 of Set 13 | bama
# Processing Record 10 of Set 13 | aswan
# Processing Record 11 of Set 13 | bontang
# Processing Record 12 of Set 13 | tigil
# Processing Record 13 of Set 13 | moree
# Processing Record 14 of Set 13 | cascais
# Processing Record 15 of Set 13 | atocha
# Processing Record 16 of Set 13 | rabo de peixe
# Processing Record 17 of Set 13 | buchanan
# Processing Record 18 of Set 13 | manyana
# Processing Record 19 of Set 13 | nyurba
# Processing Record 20 of Set 13 | mana
# Processing Record 21 of Set 13 | dunkwa
# Processing Record 22 of Set 13 | espita
# Processing Record 23 of Set 13 | bolungarvik
# City not found. Skipping...
# Processing Record 24 of Set 13 | chernyshevskiy
# Processing Record 25 of Set 13 | bodden town
# Processing Record 26 of Set 13 | marsh harbour
# Processing Record 27 of Set 13 | puerto quijarro
# Processing Record 28 of Set 13 | umm kaddadah
# Processing Record 29 of Set 13 | balkanabat
# Processing Record 30 of Set 13 | verkhniy baskunchak
# Processing Record 31 of Set 13 | apricena
# Processing Record 32 of Set 13 | sola
# Processing Record 33 of Set 13 | maceio
# Processing Record 34 of Set 13 | sept-iles
# Processing Record 35 of Set 13 | aksu
# Processing Record 36 of Set 13 | yantal
# Processing Record 37 of Set 13 | kattivakkam
# Processing Record 38 of Set 13 | gat
# Processing Record 39 of Set 13 | tambun
# Processing Record 40 of Set 13 | moron
# Processing Record 41 of Set 13 | kigoma
# Processing Record 42 of Set 13 | katherine
# Processing Record 43 of Set 13 | werda
# Processing Record 44 of Set 13 | mazagao
# Processing Record 45 of Set 13 | cuyo
# Processing Record 46 of Set 13 | santa rosalia
# Processing Record 47 of Set 13 | boyolangu
# Processing Record 48 of Set 13 | talnakh
# Processing Record 49 of Set 13 | karratha
# Processing Record 50 of Set 13 | abnub
# Processing Record 1 of Set 14 | matara
# Processing Record 2 of Set 14 | bukama
# Processing Record 3 of Set 14 | tazmalt
# Processing Record 4 of Set 14 | tezu
# Processing Record 5 of Set 14 | mayor pablo lagerenza
# Processing Record 6 of Set 14 | mattawa
# Processing Record 7 of Set 14 | prince rupert
# Processing Record 8 of Set 14 | batemans bay
# Processing Record 9 of Set 14 | talcahuano
# Processing Record 10 of Set 14 | korla
# Processing Record 11 of Set 14 | sehithwa
# Processing Record 12 of Set 14 | chunskiy
# Processing Record 13 of Set 14 | ramanuj ganj
# Processing Record 14 of Set 14 | los llanos de aridane
# Processing Record 15 of Set 14 | orange
# Processing Record 16 of Set 14 | podporozhye
# Processing Record 17 of Set 14 | avera
# Processing Record 18 of Set 14 | minnedosa
# Processing Record 19 of Set 14 | amapa
# Processing Record 20 of Set 14 | odienne
# Processing Record 21 of Set 14 | olinda
# Processing Record 22 of Set 14 | sao joao de pirabas
# Processing Record 23 of Set 14 | tuatapere
# Processing Record 24 of Set 14 | muli
# Processing Record 25 of Set 14 | gushikawa
# Processing Record 26 of Set 14 | nizhniy ingash
# Processing Record 27 of Set 14 | egvekinot
# Processing Record 28 of Set 14 | san andres
# Processing Record 29 of Set 14 | banepa
# Processing Record 30 of Set 14 | vilyuysk
# Processing Record 31 of Set 14 | hobyo
# Processing Record 32 of Set 14 | plaster rock
# Processing Record 33 of Set 14 | daru
# Processing Record 34 of Set 14 | la grande
# Processing Record 35 of Set 14 | flagstaff
# Processing Record 36 of Set 14 | katangli
# Processing Record 37 of Set 14 | portobelo
# Processing Record 38 of Set 14 | dire
# Processing Record 39 of Set 14 | tullow
# Processing Record 40 of Set 14 | aguimes
# Processing Record 41 of Set 14 | mount gambier
# Processing Record 42 of Set 14 | ellensburg
# Processing Record 43 of Set 14 | visby
# Processing Record 44 of Set 14 | talpa
# Processing Record 45 of Set 14 | karpuninskiy
# City not found. Skipping...
# Processing Record 46 of Set 14 | tabiauea
# City not found. Skipping...
# Processing Record 47 of Set 14 | deszk
# Processing Record 48 of Set 14 | seaford
# Processing Record 49 of Set 14 | lethem
# Processing Record 50 of Set 14 | quelimane
# Processing Record 1 of Set 15 | talaya
# Processing Record 2 of Set 15 | curup
# Processing Record 3 of Set 15 | chiredzi
# Processing Record 4 of Set 15 | kushmurun
# Processing Record 5 of Set 15 | richards bay
# Processing Record 6 of Set 15 | suntar
# Processing Record 7 of Set 15 | topi
# Processing Record 8 of Set 15 | altay
# Processing Record 9 of Set 15 | udayagiri
# Processing Record 10 of Set 15 | porgera
# Processing Record 11 of Set 15 | maumere
# Processing Record 12 of Set 15 | villa oliva
# City not found. Skipping...
# Processing Record 13 of Set 15 | denia
# Processing Record 14 of Set 15 | toliary
# City not found. Skipping...
# Processing Record 15 of Set 15 | mareeba
# Processing Record 16 of Set 15 | miraflores
# Processing Record 17 of Set 15 | hadejia
# Processing Record 18 of Set 15 | koupela
# Processing Record 19 of Set 15 | karauzyak
# City not found. Skipping...
# Processing Record 20 of Set 15 | rudbar
# Processing Record 21 of Set 15 | nadym
# Processing Record 22 of Set 15 | butembo
# Processing Record 23 of Set 15 | puerto del rosario
# Processing Record 24 of Set 15 | kerki
# City not found. Skipping...
# Processing Record 25 of Set 15 | port keats
# Processing Record 26 of Set 15 | pafos
# Processing Record 27 of Set 15 | itarema
# Processing Record 28 of Set 15 | sri aman
# Processing Record 29 of Set 15 | shitanjing
# Processing Record 30 of Set 15 | pointe michel
# Processing Record 31 of Set 15 | virginia beach
# Processing Record 32 of Set 15 | luancheng
# Processing Record 33 of Set 15 | lensk
# Processing Record 34 of Set 15 | salinas
# Processing Record 35 of Set 15 | gracac
# Processing Record 36 of Set 15 | anadyr
# Processing Record 37 of Set 15 | inta
# Processing Record 38 of Set 15 | bikaner
# Processing Record 39 of Set 15 | khipro
# Processing Record 40 of Set 15 | anloga
# Processing Record 41 of Set 15 | jiddah
# City not found. Skipping...
# Processing Record 42 of Set 15 | aporawan
# City not found. Skipping...
# Processing Record 43 of Set 15 | gazanjyk
# Processing Record 44 of Set 15 | papasquiaro
# City not found. Skipping...
# Processing Record 45 of Set 15 | humberto de campos
# Processing Record 46 of Set 15 | balkhash
# Processing Record 47 of Set 15 | high level
# Processing Record 48 of Set 15 | zunyi
# Processing Record 49 of Set 15 | copiapo
# Processing Record 50 of Set 15 | howard springs
# Processing Record 1 of Set 16 | sondershausen
# Processing Record 2 of Set 16 | muriti
# Processing Record 3 of Set 16 | vakhrushev
# Processing Record 4 of Set 16 | paucartambo
# City not found. Skipping...
# Processing Record 5 of Set 16 | kibala
# Processing Record 6 of Set 16 | atbasar
# Processing Record 7 of Set 16 | porto belo
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Luanda  -8.8368   13.2343     71.60        83          67
# 1         Fortuna  40.5982 -124.1573     61.86        90         100
# 2            Sibu   2.3000  111.8167     71.91        94          40
# 3      Nouakchott  18.0858  -15.9785     78.73        72           0
# 4          Marawi   7.9986  124.2928     68.77        95         100
# 5    Longyearbyen  78.2186   15.6401     48.04        81          75
# 6           Vaini -21.2000 -175.2000     73.56        94          40
# 7          Faanui -16.4833 -151.7500     80.04        69          19
# 8       Stornoway  58.2093   -6.3865     57.16        81          40
# 9  Ribeira Grande  38.5167  -28.7000     72.00        83          40
#
#    Wind Speed Country Current Description
# 0        8.05      AO       broken clouds
# 1        0.00      US     overcast clouds
# 2        4.61      MY       moderate rain
# 3       14.74      MR           clear sky
# 4        2.51      PH          light rain
# 5       12.66      SJ       broken clouds
# 6        8.05      TO    scattered clouds
# 7       20.04      PF          few clouds
# 8       14.97      GB    scattered clouds
# 9        2.30      PT    scattered clouds

# %%
city_data_df.to_csv('Weather_Database.csv')
